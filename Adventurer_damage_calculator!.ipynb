# %% [markdown]
# <a href="https://colab.research.google.com/github/Chansey4759/Centurion-Showdown-Coding-services-/blob/main/Adventurer_damage_calculator!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Element_check(y):
 if i == 17:
   return("typeless")
 elif i == 18:
   return("air")
 elif i == 19:
   return("blast")
 elif i == 20:
   return("blood")
 elif i == 21:
   return("cosmic")
 elif i == 22:
   return("crystal")
 elif i == 23:
   return("dark")
 elif i == 24:
   return("dragon")
 elif i == 25:
   return("earth")
 elif i == 26:
   return("fairy")
 elif i == 27:
   return("fire")
 elif i == 28:
   return("fossil")
 elif i == 29:
   return("ghost")
 elif i == 30:
   return("ice")
 elif i == 31:
   return("insect")
 elif i == 32:
   return("lava")
 elif i == 33:
   return("light")
 elif i == 34:
   return("magic")
 elif i == 35:
   return("martial")
 elif i == 36:
   return("metal")
 elif i == 37:
   return("nature")
 elif i == 38:
   return("poison")
 elif i == 39:
   return("psychic")
 elif i == 40:
   return("radiation")
 elif i == 41:
   return("rock")
 elif i == 42:
   return("sound")
 elif i == 43:
   return("tech")
 elif i == 44:
   return("thunder")
 elif i == 45:
   return("water")
 else:
  return("typeless")





Elementtracker = {"typeless": 17,
"air": 18,
"blast": 19,
"blood": 20,
"cosmic": 21,
"crystal": 22,
"dark": 23,
"dragon": 24,
"earth": 25,
"fairy": 26,
"fire": 27,
"fossil": 28,
"ghost": 29,
"ice": 30,
"insect": 31,
"lava": 32,
"light": 33,
"magic": 34,
"martial": 35,
"metal": 36,
"nature": 37,
"poison": 38,
"psychic": 39,
"radiation": 40,
"rock": 41,
"sound": 42,
"tech": 43,
"thunder": 44,
"water": 45}


# {PLACEHOLDER VALUE FOR x)
x = __builtins__.int(0)
# REMINDER:
# "Element" = first attacking element
# "ELementATK" = second attacking element
# "Element1" = first defending element
# "ElementDEF" = second defending element

# Below is Actively changing numbers, above are constants that aren't primarily affected by user input.
print("Type in the attacker's current attacking stat!")
ATK = __builtins__.int(input())
print("Type in your first attacking element")
Elementtracker1 = input().lower()

i = 17
y = i
while (Elementtracker1 != Elementtracker[Element_check(y)]) and i in range(17, 46):
   i += 1
   if Element_check(y) == Elementtracker1: break
   else: pass

if i > 45 and (Elementtracker1 != Elementtracker[Element_check(y)]):
  Elementtracker1 = "typeless"
else: pass
Element = Elementtracker1




# ________________________________________________________________________ 2nd attacking element
print("Type in your second attacking element!")
Elementtracker1 = input().lower()
i = 17
y == i

while (Elementtracker1 != Elementtracker[Element_check(y)]) and i in range(17, 46):
   i += 1
   if Element_check(y) == Elementtracker1: break
   else: pass

if i > 45 and (Elementtracker1 != Elementtracker[Element_check(y)]):
  Elementtracker1 = "typeless"
else: pass
ElementATK = Elementtracker1



# ___________________________________________________________________________________________________
print("Type in the defender's DEF stat!")
DEF = __builtins__.int(input())
print("Type in the defender's first element!")
Elementtracker1 = input().lower()

i = 17
y == i
while (Elementtracker1 != Elementtracker[Element_check(y)]) and i in range(17, 46):
   i += 1
   if Element_check(y) == Elementtracker1: break
   else: pass

if i > 45 and (Elementtracker1 != Elementtracker[Element_check(y)]):
  Elementtracker1 = "typeless"
else: pass
Element1 = Elementtracker1

# ________________________________________________________________________ 2nd defending element
print("Type in the defender's second element!")
Elementtracker1 = input().lower()
i = 17
y == i
while (Elementtracker1 != Elementtracker[Element_check(y)]) and i in range(17, 46):
   i += 1
   if Element_check(y) == Elementtracker1: break
   else: pass

if i > 45 and (Elementtracker1 != Elementtracker[Element_check(y)]):
  Elementtracker1 = "typeless"
else: pass
ElementDEF = Elementtracker1
# ________________________________________________________________________ 2nd defending element
print("Type in the defender's third element!")
Elementtracker1 = input().lower()
i = 17
y == i
while (Elementtracker1 != Elementtracker[Element_check(y)]) and i in range(17, 46):
   i += 1
   if Element_check(y) == Elementtracker1: break
   else: pass

if i > 45 and (Elementtracker1 != Elementtracker[Element_check(y)]):
  Elementtracker1 = "typeless"
else: pass
ElementDEF1 = Elementtracker1
# ________________________________________________________________________ 2nd defending element
print("Type in the defender's forth element!")
Elementtracker1 = input().lower()
i = 17
y == i
while (Elementtracker1 != Elementtracker[Element_check(y)]) and i in range(17, 46):
   i += 1
   if Element_check(y) == Elementtracker1: break
   else: pass

if i > 45 and (Elementtracker1 != Elementtracker[Element_check(y)]):
  Elementtracker1 = "typeless"
else: pass
ElementDEF2 = Elementtracker1

#_______________________________ Jumpstarts each elemental interaction check: Elementkicker

Elementkicker = [Element, ElementATK, Element1, ElementDEF, ElementDEF1, ElementDEF2]


# ___________________________IMMUNITY TRACKER, DO NOT TOUCH ONCE FINISHED!!!!!!!__________________________________________________
b = __builtins__.int(1)
i = __builtins__.int(0)
for i in range (0, 2):
  if str(Elementkicker[i]) in 'blast':
    i = __builtins__.int(2)
    for i in range (2, 6):
      if str(Elementkicker[i]) in ('sound', 'radiation'):
        b = __builtins__.int(0)
        i = __builtins__.int(0)
        break
      elif i >= 5: i = __builtins__.int(0)
    else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'blood':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('insect', 'lava', 'metal', 'radiation'):
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)

for i in range (0, 2):
    if str(Elementkicker[i]) in 'crystal':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'thunder':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)



for i in range (0, 2):
    if str(Elementkicker[i]) in 'earth':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'air':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)



for i in range (0, 2):
    if str(Elementkicker[i]) in 'fire':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'radiation':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)




for i in range (0, 2):
    if str(Elementkicker[i]) in 'ice':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'lava':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else:
          i = __builtins__.int(0)
          break



for i in range (0, 2):
    if str(Elementkicker[i]) in 'lava':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('cosmic', 'lava', 'water'):
            print("yes")
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'light':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'radiation':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)



for i in range (0, 2):
    if str(Elementkicker[i]) in 'martial':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'ghost':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'nature':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'lava':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)





for i in range (0, 2):
    if str(Elementkicker[i]) in 'poison':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('cosmic', 'crystal', 'earth', 'metal', 'poison'):
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'psychic':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'dark':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'radiation':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('ghost', 'lava', 'light'):
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'rock':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('cosmic', 'lava'):
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'sound':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('cosmic', 'earth'):
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


for i in range (0, 2):
    if str(Elementkicker[i]) in 'tech':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'thunder':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)

for i in range (0, 2):
    if str(Elementkicker[i]) in 'thunder':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in ('earth', 'fossil', 'lava'):
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)

for i in range (0, 2):
    if str(Elementkicker[i]) in 'water':
        i = __builtins__.int(2)
        for i in range (2, 6):
          if str(Elementkicker[i]) in 'lava':
            b = __builtins__.int(0)
            i = __builtins__.int(0)
            break
          elif i >= 5: i = __builtins__.int(0)
        else: i = __builtins__.int(0)


# _________________End of immunity tracker____________________________________________________________________________________________________________________________


# START OF ELEMENTAL DAMAGE MULTIPLIERS (28/28 done)
if Elementkicker[0] == "air" or Elementkicker[1] == "air":
  if Elementkicker[2] in ["fairy", "insect", "martial", "nature"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["fairy", "insect", "martial", "nature"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["fairy", "insect", "martial", "nature"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["fairy", "insect", "martial", "nature"]:
    x += 1
  else: pass


  if Elementkicker[2] in ["cosmic","crystal", "fossil", "ice", "lava", "metal", "rock", "tech", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic","crystal", "fossil", "ice", "lava", "metal", "rock", "tech", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic","crystal", "fossil", "ice", "lava", "metal", "rock", "tech", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic","crystal", "fossil", "ice", "lava", "metal", "rock", "tech", "thunder"]:
    x -= 1
  else: pass

else: pass

if Elementkicker[0] == "blast" or Elementkicker[1] == "blast":
  if Elementkicker[2] in ["air", "cosmic", "crystal", "dark", "earth", "fossil",  "ice", "lava", "metal", "nature", "rock", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "cosmic", "crystal", "dark", "earth", "fossil",  "ice", "lava", "metal", "nature", "rock", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "cosmic", "crystal", "dark", "earth", "fossil",  "ice", "lava", "metal", "nature", "rock", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "cosmic", "crystal", "dark", "earth", "fossil",  "ice", "lava", "metal", "nature", "rock", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["dragon", "fire", "ghost", "insect", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["dragon", "fire", "ghost", "insect", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["dragon", "fire", "ghost", "insect", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["dragon", "fire", "ghost", "insect", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "blood" or Elementkicker[1] == "blood":
  if Elementkicker[2] in ["blood", "fairy", "fire", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blood", "fairy", "fire", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blood", "fairy", "fire", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blood", "fairy", "fire", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "cosmic", "crystal", "fossil", "ghost", "poison", "rock", "thunder", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "cosmic", "crystal", "fossil", "ghost", "poison", "rock", "thunder", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "cosmic", "crystal", "fossil", "ghost", "poison", "rock", "thunder", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "cosmic", "crystal", "fossil", "ghost", "poison", "rock", "thunder", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "cosmic" or Elementkicker[1] == "cosmic":
  if Elementkicker[2] in ["air", "crystal", "dark", "earth", "lava", "light", "metal", "nature", "radiation", "rock", "sound"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "crystal", "dark", "earth", "lava", "light", "metal", "nature", "radiation", "rock", "sound"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "crystal", "dark", "earth", "lava", "light", "metal", "nature", "radiation", "rock", "sound"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "crystal", "dark", "earth", "lava", "light", "metal", "nature", "radiation", "rock", "sound"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "fire", "ice", "tech", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "fire", "ice", "tech", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "fire", "ice", "tech", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "fire", "ice", "tech", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "crystal" or Elementkicker[1] == "crystal":
  if Elementkicker[2] in ["air", "fire", "fossil", "ice", "insect", "lava", "magic", "radiation", "rock"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "fire", "fossil", "ice", "insect", "lava", "magic", "radiation", "rock"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "fire", "fossil", "ice", "insect", "lava", "magic", "radiation", "rock"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "fire", "fossil", "ice", "insect", "lava", "magic", "radiation", "rock"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "blood", "cosmic", "earth", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "blood", "cosmic", "earth", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "blood", "cosmic", "earth", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "blood", "cosmic", "earth", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
else: pass


if Elementkicker[0] == "dark" or Elementkicker[1] == "dark":
  if Elementkicker[2] in ["blast", "ghost", "light", "magic", "psychic"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blast", "ghost", "light", "magic", "psychic"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blast", "ghost", "light", "magic", "psychic"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blast", "ghost", "light", "magic", "psychic"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["cosmic", "fairy", "insect", "martial"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic", "fairy", "insect", "martial"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic", "fairy", "insect", "martial"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic", "fairy", "insect", "martial"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "dragon" or Elementkicker[1] == "dragon":
  if Elementkicker[2] in ["dragon", "lava", "magic", "metal", "radiation"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["dragon", "lava", "magic", "metal", "radiation"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["dragon", "lava", "magic", "metal", "radiation"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["dragon", "lava", "magic", "metal", "radiation"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["cosmic", "fairy", "ice"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic", "fairy", "ice"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic", "fairy", "ice"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic", "fairy", "ice"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "earth" or Elementkicker[1] == "earth":
  if Elementkicker[2] in ["blast", "crystal", "fire", "fossil", "light", "metal", "poison", "radiation", "rock", "sound", "tech", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blast", "crystal", "fire", "fossil", "light", "metal", "poison", "radiation", "rock", "sound", "tech", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blast", "crystal", "fire", "fossil", "light", "metal", "poison", "radiation", "rock", "sound", "tech", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blast", "crystal", "fire", "fossil", "light", "metal", "poison", "radiation", "rock", "sound", "tech", "thunder"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["cosmic", "ice", "insect", "lava", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic", "ice", "insect", "lava", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic", "ice", "insect", "lava", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic", "ice", "insect", "lava", "nature", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "fairy" or Elementkicker[1] == "fairy":
  if Elementkicker[2] in ["dark", "dragon", "magic", "martial"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["dark", "dragon", "magic", "martial"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["dark", "dragon", "magic", "martial"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["dark", "dragon", "magic", "martial"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["air", "blood", "crystal", "insect", "metal", "poison"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["air", "blood", "crystal", "insect", "metal", "poison"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["air", "blood", "crystal", "insect", "metal", "poison"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["air", "blood", "crystal", "insect", "metal", "poison"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "fire" or Elementkicker[1] == "fire":
  if Elementkicker[2] in ["ice", "insect", "metal", "nature", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["ice", "insect", "metal", "nature", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["ice", "insect", "metal", "nature", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["ice", "insect", "metal", "nature", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "blood", "cosmic", "crystal", "dragon", "earth", "fire", "fossil", "lava", "rock", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "blood", "cosmic", "crystal", "dragon", "earth", "fire", "fossil", "lava", "rock", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "blood", "cosmic", "crystal", "dragon", "earth", "fire", "fossil", "lava", "rock", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "blood", "cosmic", "crystal", "dragon", "earth", "fire", "fossil", "lava", "rock", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "fossil" or Elementkicker[1] == "fossil":
  if Elementkicker[2] in ["air", "fire", "ice", "insect", "rock"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "fire", "ice", "insect", "rock"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "fire", "ice", "insect", "rock"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "fire", "ice", "insect", "rock"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "cosmic", "crystal", "earth", "lava", "martial", "metal", "nature", "radiation", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "cosmic", "crystal", "earth", "lava", "martial", "metal", "nature", "radiation", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "cosmic", "crystal", "earth", "lava", "martial", "metal", "nature", "radiation", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "cosmic", "crystal", "earth", "lava", "martial", "metal", "nature", "radiation", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "ghost" or Elementkicker[1] == "ghost":
  if Elementkicker[2] in ["ghost", "martial", "psychic", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["ghost", "martial", "psychic", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["ghost", "martial", "psychic", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["ghost", "martial", "psychic", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["dark", "light", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["dark", "light", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["dark", "light", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["dark", "light", "magic"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "ice" or Elementkicker[1] == "ice":
  if Elementkicker[2] in ["air", "cosmic", "dragon", "earth", "insect", "nature", "radiation", "water"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "cosmic", "dragon", "earth", "insect", "nature", "radiation", "water"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "cosmic", "dragon", "earth", "insect", "nature", "radiation", "water"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "cosmic", "dragon", "earth", "insect", "nature", "radiation", "water"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "blood", "crystal", "fire", "fossil", "ice", "martial", "metal", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "blood", "crystal", "fire", "fossil", "ice", "martial", "metal", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "blood", "crystal", "fire", "fossil", "ice", "martial", "metal", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "blood", "crystal", "fire", "fossil", "ice", "martial", "metal", "rock"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "insect" or Elementkicker[1] == "insect": # Halfway there! 14/28
  if Elementkicker[2] in ["blood", "earth", "fairy", "nature", "poison", "psychic"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blood", "earth", "fairy", "nature", "poison", "psychic"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blood", "earth", "fairy", "nature", "poison", "psychic"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blood", "earth", "fairy", "nature", "poison", "psychic"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["air", "crystal", "fire", "fossil", "ice", "lava", "light", "metal", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["air", "crystal", "fire", "fossil", "ice", "lava", "light", "metal", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["air", "crystal", "fire", "fossil", "ice", "lava", "light", "metal", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["air", "crystal", "fire", "fossil", "ice", "lava", "light", "metal", "radiation", "rock"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "lava" or Elementkicker[1] == "lava":
  if Elementkicker[2] in ["blast", "blood", "fairy", "fire", "fossil", "ice", "insect", "metal", "nature", "poison", "radiation", "rock", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blast", "blood", "fairy", "fire", "fossil", "ice", "insect", "metal", "nature", "poison", "radiation", "rock", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blast", "blood", "fairy", "fire", "fossil", "ice", "insect", "metal", "nature", "poison", "radiation", "rock", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blast", "blood", "fairy", "fire", "fossil", "ice", "insect", "metal", "nature", "poison", "radiation", "rock", "thunder"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["crystal", "dragon", "earth", "ghost", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["crystal", "dragon", "earth", "ghost", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["crystal", "dragon", "earth", "ghost", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["crystal", "dragon", "earth", "ghost", "magic"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "light" or Elementkicker[1] == "light":
  if Elementkicker[2] in ["dark", "ghost", "sound"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["dark", "ghost", "sound"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["dark", "ghost", "sound"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["dark", "ghost", "sound"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["cosmic", "earth", "fire", "nature"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic", "earth", "fire", "nature"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic", "earth", "fire", "nature"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic", "earth", "fire", "nature"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "magic" or Elementkicker[1] == "magic":
  if Elementkicker[2] in ["blood", "cosmic", "crystal", "ghost", "martial", "metal", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blood", "cosmic", "crystal", "ghost", "martial", "metal", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blood", "cosmic", "crystal", "ghost", "martial", "metal", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blood", "cosmic", "crystal", "ghost", "martial", "metal", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["dark", "dragon", "fairy", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["dark", "dragon", "fairy", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["dark", "dragon", "fairy", "magic"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["dark", "dragon", "fairy", "magic"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "martial" or Elementkicker[1] == "martial":
  if Elementkicker[2] in ["crystal", "dark", "fossil", "ice", "metal", "rock"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["crystal", "dark", "fossil", "ice", "metal", "rock"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["crystal", "dark", "fossil", "ice", "metal", "rock"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["crystal", "dark", "fossil", "ice", "metal", "rock"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["air", "cosmic", "fairy", "insect", "lava", "magic", "psychic", "radiation", "sound"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["air", "cosmic", "fairy", "insect", "lava", "magic", "psychic", "radiation", "sound"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["air", "cosmic", "fairy", "insect", "lava", "magic", "psychic", "radiation", "sound"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["air", "cosmic", "fairy", "insect", "lava", "magic", "psychic", "radiation", "sound"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "metal" or Elementkicker[1] == "metal":
  if Elementkicker[2] in ["crystal", "fairy", "fossil", "ice", "insect", "rock"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["crystal", "fairy", "fossil", "ice", "insect", "rock"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["crystal", "fairy", "fossil", "ice", "insect", "rock"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["crystal", "fairy", "fossil", "ice", "insect", "rock"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "earth", "fire", "lava", "martial", "metal", "radiation", "sound", "tech", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "earth", "fire", "lava", "martial", "metal", "radiation", "sound", "tech", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "earth", "fire", "lava", "martial", "metal", "radiation", "sound", "tech", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "earth", "fire", "lava", "martial", "metal", "radiation", "sound", "tech", "thunder"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "nature" or Elementkicker[1] == "nature":
  if Elementkicker[2] in ["crystal", "earth", "fossil", "light", "rock", "tech", "water"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["crystal", "earth", "fossil", "light", "rock", "tech", "water"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["crystal", "earth", "fossil", "light", "rock", "tech", "water"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["crystal", "earth", "fossil", "light", "rock", "tech", "water"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["air", "blast", "cosmic", "dragon", "fire", "ice", "insect", "poison"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["air", "blast", "cosmic", "dragon", "fire", "ice", "insect", "poison"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["air", "blast", "cosmic", "dragon", "fire", "ice", "insect", "poison"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["air", "blast", "cosmic", "dragon", "fire", "ice", "insect", "poison"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "poison" or Elementkicker[1] == "poison":
  if Elementkicker[2] in ["blood", "fairy", "insect", "martial", "nature", "water"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blood", "fairy", "insect", "martial", "nature", "water"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blood", "fairy", "insect", "martial", "nature", "water"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blood", "fairy", "insect", "martial", "nature", "water"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["dragon", "fossil", "ghost", "lava", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["dragon", "fossil", "ghost", "lava", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["dragon", "fossil", "ghost", "lava", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["dragon", "fossil", "ghost", "lava", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "psychic" or Elementkicker[1] == "psychic":
  if Elementkicker[2] in ["magic", "martial", "poison", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["magic", "martial", "poison", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["magic", "martial", "poison", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["magic", "martial", "poison", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["cosmic", "fairy", "ghost", "lava", "sound"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic", "fairy", "ghost", "lava", "sound"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic", "fairy", "ghost", "lava", "sound"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic", "fairy", "ghost", "lava", "sound"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "radiation" or Elementkicker[1] == "radiation":
  if Elementkicker[2] in ["air", "blast", "blood", "earth", "ice", "insect", "martial", "nature", "poison", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "blast", "blood", "earth", "ice", "insect", "martial", "nature", "poison", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "blast", "blood", "earth", "ice", "insect", "martial", "nature", "poison", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "blast", "blood", "earth", "ice", "insect", "martial", "nature", "poison", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["cosmic", "dark", "magic", "metal", "sound", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["cosmic", "dark", "magic", "metal", "sound", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["cosmic", "dark", "magic", "metal", "sound", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["cosmic", "dark", "magic", "metal", "sound", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "rock" or Elementkicker[1] == "rock":
  if Elementkicker[2] in ["air", "fire", "ice", "insect", "radiation", "tech", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "fire", "ice", "insect", "radiation", "tech", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "fire", "ice", "insect", "radiation", "tech", "thunder"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "fire", "ice", "insect", "radiation", "tech", "thunder"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "dark", "earth", "ghost", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "dark", "earth", "ghost", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "dark", "earth", "ghost", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "dark", "earth", "ghost", "martial", "metal", "nature", "water"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "sound" or Elementkicker[1] == "sound":
  if Elementkicker[2] in ["air", "crystal", "ice", "metal"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "crystal", "ice", "metal"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "crystal", "ice", "metal"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "crystal", "ice", "metal"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["ghost", "insect", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["ghost", "insect", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["ghost", "insect", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["ghost", "insect", "psychic", "radiation", "rock"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "tech" or Elementkicker[1] == "tech":
  if Elementkicker[2] in ["blood", "cosmic", "dark", "fossil", "lava", "magic", "martial", "radiation", "sound"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blood", "cosmic", "dark", "fossil", "lava", "magic", "martial", "radiation", "sound"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blood", "cosmic", "dark", "fossil", "lava", "magic", "martial", "radiation", "sound"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blood", "cosmic", "dark", "fossil", "lava", "magic", "martial", "radiation", "sound"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blast", "earth", "fairy", "fire", "ghost"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blast", "earth", "fairy", "fire", "ghost"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blast", "earth", "fairy", "fire", "ghost"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blast", "earth", "fairy", "fire", "ghost"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "thunder" or Elementkicker[1] == "thunder":
  if Elementkicker[2] in ["air", "blood", "light", "metal", "poison", "tech", "water"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["air", "blood", "light", "metal", "poison", "tech", "water"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["air", "blood", "light", "metal", "poison", "tech", "water"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["air", "blood", "light", "metal", "poison", "tech", "water"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["crystal", "dragon", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["crystal", "dragon", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["crystal", "dragon", "radiation", "rock"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["crystal", "dragon", "radiation", "rock"]:
    x -= 1
  else: pass
else: pass

if Elementkicker[0] == "water" or Elementkicker[1] == "water":
  if Elementkicker[2] in ["blast", "crystal", "earth", "fire", "fossil", "insect", "rock", "tech"]:
    x += 1
  else: pass
  if Elementkicker[3] in ["blast", "crystal", "earth", "fire", "fossil", "insect", "rock", "tech"]:
    x += 1
  else: pass
  if Elementkicker[4] in ["blast", "crystal", "earth", "fire", "fossil", "insect", "rock", "tech"]:
    x += 1
  else: pass
  if Elementkicker[5] in ["blast", "crystal", "earth", "fire", "fossil", "insect", "rock", "tech"]:
    x += 1
  else: pass

  if Elementkicker[2] in ["blood", "cosmic", "dragon", "ice", "nature", "poison", "radiation", "sound", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[3] in ["blood", "cosmic", "dragon", "ice", "nature", "poison", "radiation", "sound", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[4] in ["blood", "cosmic", "dragon", "ice", "nature", "poison", "radiation", "sound", "thunder"]:
    x -= 1
  else: pass
  if Elementkicker[5] in ["blood", "cosmic", "dragon", "ice", "nature", "poison", "radiation", "sound", "thunder"]:
    x -= 1
  else: pass
else: pass
#______________________________________________________________ END OF ELEMENTAL INTERACTIONS__________________________________________________________________________________________

# test if 100, ice, lava, 5, air, blast, blood, water should print a 0
if (DEF != 0) and (x >= 1):
 DEF = __builtins__.int(0)
 x -= 1
else:
  pass

damage = (ATK * (2**x)) - (DEF)
if damage < 0 or b == __builtins__.int(0):
    print(0)
else:
    print(damage)
